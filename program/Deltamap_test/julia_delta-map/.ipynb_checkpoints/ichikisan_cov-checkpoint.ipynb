# %%
import pandas as pd

# データファイルのパスを指定
file_path = 'lblike_scalCls.dat'  # ファイルパスを実際のファイルのパスに変更してください

# データを読み込む
data = pd.read_csv(file_path, sep='\t', header=None)  # もしタブ区切りの場合は sep='\t' を指定

# 2列目を取得
second_column = data.iloc[0, 0]

# 結果を表示
print(second_column)
# Out:
#      2    0.10353E+04    0.48895E-01    0.29740E+01

# %%
import pandas as pd

# データファイルのパスを指定
file_path_scal = 'lblike_scalCls.dat'  # ファイルパスを実際のファイルのパスに変更してください
file_path_tens = 'lblike_tensCls.dat'  # ファイルパスを実際のファイルのパスに変更してください
file_path_lens = 'lblike_lensedCls.dat'  # ファイルパスを実際のファイルのパスに変更してください


# データを読み込む
data_scal = pd.read_csv(file_path_scal, delim_whitespace=True, header=None, skipinitialspace=True, engine='python')
data_tens = pd.read_csv(file_path_tens, delim_whitespace=True, header=None, skipinitialspace=True, engine='python')
data_lens = pd.read_csv(file_path_lens, delim_whitespace=True, header=None, skipinitialspace=True, engine='python')

# %%
# n列目を取得
cl_TT_s = data_scal.iloc[:, 1]
cl_EE_s = data_scal.iloc[:, 2]
cl_TE_s = data_scal.iloc[:, 3]

cl_TT_t = data_tens.iloc[:, 1]
cl_EE_t = data_tens.iloc[:, 2]
cl_BB_t = data_tens.iloc[:, 3]
cl_TE_t = data_tens.iloc[:, 4]

cl_TT_l = data_lens.iloc[:, 1]
cl_EE_l = data_lens.iloc[:, 2]
cl_BB_l = data_lens.iloc[:, 3]
cl_TE_l = data_lens.iloc[:, 4]

# 結果を表示
print(cl_EE_s)
# Out:
# 0       0.048895
# 1       0.079579
# 2       0.088730
# 3       0.077842
# 4       0.056774
#           ...
# 2042    6.555500
# 2043    6.480600
# 2044    6.405700
# 2045    6.330800
# 2046    6.255900
# Name: 2, Length: 2047, dtype: float64

# %%
import numpy as np
cl_TT_s = np.array(cl_TT_s)
cl_EE_s = np.array(cl_EE_s)
cl_TE_s = np.array(cl_TE_s)

cl_TT_t = np.array(cl_TT_t)
cl_EE_t = np.array(cl_EE_t)
cl_BB_t = np.array(cl_BB_t)
cl_TE_t = np.array(cl_TE_t)

cl_TT_l = np.array(cl_TT_l)
cl_EE_l = np.array(cl_EE_l)
cl_BB_l = np.array(cl_BB_l)
cl_TE_l = np.array(cl_TE_l)

# %%
ell = np.arange(2, 2049, 1)

# %%
import matplotlib.pyplot as plt

#plot#
fig = plt.figure(figsize=(9, 6))

#plt.loglog(ell, cl_TT_s, lw = 2.2, label="Clean Map TT")
plt.loglog(ell, cl_EE_s, lw = 2.2, label="Clean Map EE")

plt.ylabel(r'$C_\ell^{BB}/ (\mu{\rm K}^2)$', fontsize=16)
plt.xlabel(r'$\ell$', fontsize=16)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.title("Power spectrum", fontsize=16)

plt.grid()
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

#plot#
fig = plt.figure(figsize=(9, 6))

#plt.loglog(ell, cl_TT_t, lw = 2.2, label="Clean Map TT")
plt.loglog(ell, cl_EE_t, lw = 2.2, label="Clean Map EE")
plt.loglog(ell, cl_BB_t, lw = 2.2, label="Clean Map BB")


plt.ylabel(r'$C_\ell^{BB}/ (\mu{\rm K}^2)$', fontsize=16)
plt.xlabel(r'$\ell$', fontsize=16)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.title("Power spectrum", fontsize=16)

plt.grid()
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

ell_2 = np.arange(2, 1751, 1)

#plot#
fig = plt.figure(figsize=(9, 6))

#plt.loglog(ell, cl_TT_l, lw = 2.2, label="Clean Map TT")
plt.loglog(ell_2, cl_EE_l, lw = 2.2, label="Clean Map EE")
plt.loglog(ell_2, cl_BB_l, lw = 2.2, label="Clean Map BB")


plt.ylabel(r'$C_\ell^{BB}/ (\mu{\rm K}^2)$', fontsize=16)
plt.xlabel(r'$\ell$', fontsize=16)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.title("Power spectrum", fontsize=16)

plt.grid()
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

#plot#
fig = plt.figure(figsize=(9, 6))

#plt.loglog(ell, cl_TT_s, lw = 2.2, label="Clean Map TT")
plt.loglog(ell, cl_EE_s, lw = 2.2, label="Clean Map EE")
plt.loglog(ell, cl_BB_t, lw = 2.2, label="Clean Map EE")
plt.loglog(ell_2, cl_BB_l, lw = 2.2, label="Clean Map EE")

plt.ylabel(r'$C_\ell^{BB}/ (\mu{\rm K}^2)$', fontsize=16)
plt.xlabel(r'$\ell$', fontsize=16)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.title("Power spectrum", fontsize=16)

plt.grid()
plt.legend()

plt.show()

# %%
import sys
sys.path.append('/Users/ikumakiyoshi/Library/Mobile Documents/com~apple~CloudDocs/study_fg_rm/program/Deltamap_test/Python_delta_map/function')
import noise_make as ns
import fg_make_file as fg
import cmb_make_file as cmb
import alpha_Delta_map as dm
import healpy as hp
import numpy as np
# Out:
# Using CAMB 1.5.2 installed at /Users/ikumakiyoshi/.julia/conda/3/lib/python3.10/site-packages/camb

# %%
random_seed_cmb = 5123
seed_syn = 5123
nside = 2**10
r= 0.01

# %%
cl_scal, cl_lens, cl_tens = cmb.cmb_cell_make(nside, random_seed_cmb, seed_syn)
# Out:
#  WARNING: nu_mass_degeneracies ignored when share_delta_neff

# %%
cl_scal = cl_scal.T

# %%
cl_lens = cl_lens.T

# %%
cl_tens = cl_tens.T

# %%
import math

ell_1 = np.arange(2, 2051, 1)

dl_scal = cl_scal * ell_1 * (ell_1 + 1) / (2 * math.pi)

dl_tens = cl_tens * ell_1 * (ell_1 + 1) / (2 * math.pi)

dl_lens = cl_lens * ell_1 * (ell_1 + 1) / (2 * math.pi)

# %%
import matplotlib.pyplot as plt

#plot#
fig = plt.figure(figsize=(9, 6))

#plt.loglog(ell, cl_TT_t, lw = 2.2, label="Clean Map TT")
plt.loglog(ell_1, dl_scal[1], lw = 2.2, label="Clean Map EE")
plt.loglog(ell_1, dl_tens[2], lw = 2.2, label="Clean Map BB")
plt.loglog(ell_1, dl_lens[2], lw = 2.2, label="Clean Map BB")


plt.ylabel(r'$C_\ell^{BB}/ (\mu{\rm K}^2)$', fontsize=16)
plt.xlabel(r'$\ell$', fontsize=16)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.title("Power spectrum", fontsize=16)

plt.grid()
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

#plot#
fig = plt.figure(figsize=(9, 6))

#plt.loglog(ell, cl_TT_t, lw = 2.2, label="Clean Map TT")
plt.loglog(ell_1, dl_scal[1], lw = 2.2, label="Cell EE")
plt.loglog(ell_1, dl_tens[2], lw = 2.2, label="Cell BB")
plt.loglog(ell_1, dl_lens[2], lw = 2.2, label="Cell BB")

plt.loglog(ell, cl_EE_s, lw = 2.2, label="Cell EE")
plt.loglog(ell, cl_BB_t, lw = 2.2, label="Cell EE")
plt.loglog(ell_2, cl_BB_l, lw = 2.2, label="Cell EE")


plt.ylabel(r'$C_\ell^{BB}/ (\mu{\rm K}^2)$', fontsize=16)
plt.xlabel(r'$\ell$', fontsize=16)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.title("Power spectrum", fontsize=16)

plt.grid()
plt.legend()

plt.show()
