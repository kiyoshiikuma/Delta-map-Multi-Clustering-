# %%
import pysm3
import pysm3.units as u
import healpy as hp
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
dust = pysm3.Sky(nside=2**1, preset_strings=["d0"])
synch = pysm3.Sky(nside=2**1, preset_strings=["s1"])

# %%
dust_60GHz = dust.get_emission(40 * u.GHz)

dust_100GHz = dust.get_emission(100 * u.GHz)

dust_280GHz = dust.get_emission(140 * u.GHz)

synch_60GHz = synch.get_emission(40 * u.GHz)

synch_100GHz = synch.get_emission(100 * u.GHz)

synch_280GHz = synch.get_emission(140 * u.GHz)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
dust_60GHz = dust_60GHz.to(u.uK_CMB, equivalencies=u.cmb_equivalencies(60*u.GHz))

dust_1000GHz = dust_100GHz.to(u.uK_CMB, equivalencies=u.cmb_equivalencies(100*u.GHz))

dust_280GHz = dust_280GHz.to(u.uK_CMB, equivalencies=u.cmb_equivalencies(280*u.GHz))

synch_60GHz = synch_60GHz.to(u.uK_CMB, equivalencies=u.cmb_equivalencies(60*u.GHz))

synch_1000GHz = synch_100GHz.to(u.uK_CMB, equivalencies=u.cmb_equivalencies(100*u.GHz))

synch_280GHz = synch_280GHz.to(u.uK_CMB, equivalencies=u.cmb_equivalencies(280*u.GHz))

# %%
Pd_60 = (dust_60GHz[1]**2 + dust_60GHz[2]**2)**(1/2)
Pd_100 = (dust_100GHz[1]**2 + dust_100GHz[2]**2)**(1/2)
Pd_280 = (dust_280GHz[1]**2 + dust_280GHz[2]**2)**(1/2) 

Ps_60 = (synch_60GHz[1]**2 + synch_60GHz[2]**2)**(1/2)
Ps_100 = (synch_100GHz[1]**2 + synch_100GHz[2]**2)**(1/2)
Ps_280 = (synch_280GHz[1]**2 + synch_280GHz[2]**2)**(1/2)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

plt.axes(ax1)
hp.mollview(dust_60GHz[1], min=0, max=3.64, title="40GHz Q", hold=True, unit = 'μK')

plt.axes(ax2)
hp.mollview(synch_60GHz[1], min=0, max=3.64, title="50GHz Q", hold=True, unit = 'μK')

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

plt.axes(ax1)
hp.mollview(dust_100GHz[1], min=0, max=3.64, title="100GHz Q",hold=True, unit = 'μK')

plt.axes(ax2)
hp.mollview(synch_100GHz[1], min=0, max=3.64, title="140GHz Q",hold=True, unit = 'μK')

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

plt.axes(ax1)
hp.mollview(dust_280GHz[1], min=0, max=3.64, title="280GHz Q",hold=True, unit = 'μK')

plt.axes(ax2)
hp.mollview(synch_280GHz[1], min=0, max=3.64, title="402GHz Q",hold=True, unit = 'μK')

# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

plt.axes(ax1)
hp.mollview(Pd_60, min=0, max=270, title="40GHz P", hold=True, unit = 'μK')

plt.axes(ax2)
hp.mollview(Ps_60, min=0, max=157, title="40GHz P", hold=True, unit = 'μK')

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

plt.axes(ax1)
hp.mollview(Pd_100, min=0, max=270, title="100GHz P",hold=True, unit = 'μK')

plt.axes(ax2)
hp.mollview(Ps_100, min=0, max=157, title="100GHz P",hold=True, unit = 'μK')

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

plt.axes(ax1)
hp.mollview(Pd_280, min=0, max=270, title="140GHz P",hold=True, unit = 'μK')

plt.axes(ax2)
hp.mollview(Ps_280, min=0, max=157, title="140GHz P",hold=True, unit = 'μK')

# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

plt.axes(ax1)
hp.mollview(Pd_60, min=0, max=20, title="40GHz P", hold=True, unit = 'μK')

plt.axes(ax2)
hp.mollview(Ps_60, min=0, max=20, title="40GHz P", hold=True, unit = 'μK')

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

plt.axes(ax1)
hp.mollview(Pd_100, min=0, max=20, title="100GHz P",hold=True, unit = 'μK')

plt.axes(ax2)
hp.mollview(Ps_100, min=0, max=20, title="100GHz P",hold=True, unit = 'μK')

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

plt.axes(ax1)
hp.mollview(Pd_280, min=0, max=20, title="140GHz P",hold=True, unit = 'μK')

plt.axes(ax2)
hp.mollview(Ps_280, min=0, max=20, title="140GHz P",hold=True, unit = 'μK')
